# %% [markdown]
# # Counting triangles in a trapezium
# This Python code can be used to explore the number of equilateral triangles within a trapezium as described in
# the article
# [counting equilateral triangles within a trapezium](https://dx.doi.org/10.13140/RG.2.2.11328.76800 "Researchgate")
# ![Triangles in trapezium](trapez01.svg)

# %% [markdown]
# ## Dependencies
#
# If you discover that you have missing modules to make this code run you will need to run the following command to install them.
#
# ```
# python -m pip install tabulate sklearn pandas statsmodels numpy scipy datetime
# ```

# %%
import datetime
from pandas import DataFrame
from tabulate import tabulate
from sklearn import linear_model
import statsmodels.api as sm
import numpy as np
today = datetime.date.today()
print("DATE Edited: ",today.strftime('%d %b %Y'))
# Out:
# DATE Edited:  16 Nov 2020

# %% [markdown]
# ## Traiangle sum data generation
# The triangle sum for different base and height values are generated in the following code block, the data is generated by an algorithm that checks whether each triangle is within the boundary of the trapezium i.e. a formula is not used. All variables have intuitive names and print_info boolean variable determines whether information about each trapezium is printed in detail to the standard output.
# # Case 1: base >2*height

# %%
print_info = False
max_height = 25
max_base = 35
variables_list=['b','h','b^2','b^3','h^2','h^3','h^2*b','b^2*h','b*h','Triangles']


bases =[]
heights=[]
triangle_sums=[]

# Case that b > 2h
for height_count in range (1, max_height+1):
    height = height_count
    for base_count in range (height_count+1 , max_base+1):
        base = base_count
        if ( base < 2*height):
            continue
        faceups = 0
        facedowns = 0
        for y in range(0, height + 1):
            for x in range (0,base -y + 1):
                residualright = base -y - x
                residualtop = height - y
                uptrianglesmax = min(residualright, residualtop)
                faceups = faceups + uptrianglesmax
                downtrianglesmax = min(residualright,y)
                facedowns = facedowns + downtrianglesmax
        bases.append(base)
        heights.append(height)
        triangle_sums.append(faceups + facedowns)
        if (print_info):
            print("base=",base,"  height=",height)
            print("number of facing up triangles = ", faceups)
            print("number of facing down triangles = ", facedowns)
            print("Total Number of Triangles in this Trapezium =" , faceups + facedowns)
        
npbases = np.asarray(bases)
npheights =np.asarray(heights)

triangle_data_b_gt_2h={
             'b':npbases,
             'h':npheights,
             'b^2':npbases**2,
             'b^3':npbases**3,
             'h^2':npheights**2,
             'h^3':npheights**3,
             'h^2*b': (npheights**2)*npbases,
             'b^2*h': (npbases**2)*npheights,
             'b*h':npbases*npheights,
             'Triangles':triangle_sums}


df = DataFrame(triangle_data_b_gt_2h,columns=variables_list)

X = df[variables_list[:-1]]
Y = df[variables_list[-1]]


# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)


#Using the results from regr.intercept_ regr.coef_ to contruct a formula string
formula_string='Formula b > 2h \nTriangle sum ='
if (abs(regr.intercept_)>10**-6):
    formula_string+=' {:.5f}'.format(regr.intercept_ )
    
for c, v in zip(regr.coef_, variables_list):
    if (abs(c)> 10**-6):
        formula_string+= ' +{:.4f}'.format(c) + v
        
print(formula_string+'\n')    

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Formula b > 2h
# Triangle sum = +0.3333h +-0.5000h^2 +-0.8333h^3 +1.0000h^2*b +1.0000b*h
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Triangles   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.013e+30
# Date:                Mon, 16 Nov 2020   Prob (F-statistic):               0.00
# Time:                        12:47:04   Log-Likelihood:                 7678.1
# No. Observations:                 306   AIC:                        -1.534e+04
# Df Residuals:                     296   BIC:                        -1.530e+04
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -5.116e-13      2e-12     -0.256      0.798   -4.45e-12    3.43e-12
# b           8.615e-14   3.88e-13      0.222      0.824   -6.77e-13    8.49e-13
# h              0.3333   7.97e-13   4.18e+11      0.000       0.333       0.333
# b^2        -5.687e-15   2.41e-14     -0.236      0.813   -5.31e-14    4.17e-14
# b^3        -4.198e-18   4.45e-16     -0.009      0.992   -8.79e-16    8.71e-16
# h^2           -0.5000   9.84e-14  -5.08e+12      0.000      -0.500      -0.500
# h^3           -0.8333   3.61e-15  -2.31e+14      0.000      -0.833      -0.833
# h^2*b          1.0000   4.16e-15   2.41e+14      0.000       1.000       1.000
# b^2*h        1.97e-16   2.07e-15      0.095      0.924   -3.88e-15    4.28e-15
# b*h            1.0000   7.84e-14   1.28e+13      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                       19.243   Durbin-Watson:                   0.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.780
# Skew:                           0.527   Prob(JB):                     0.000138
# Kurtosis:                       2.467   Cond. No.                     2.66e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.66e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Case 2: base < 2*height,  base = odd integer

# %%
print_info = False
max_height = 25
max_base = 35
variables_list=['b','h','b^2','b^3','h^2','h^3','h^2*b','b^2*h','b*h','Triangles']


bases =[]
heights=[]
triangle_sums=[]

# Case that b < 2h, base = odd value
for height_count in range (1, max_height+1):
    height = height_count
    for base_count in range (height_count+1 , max_base+1):
        base = base_count
        if ( base > 2*height or not(base%2)):
            continue
        faceups = 0
        facedowns = 0
        for y in range(0, height + 1):
            for x in range (0,base -y + 1):
                residualright = base -y - x
                residualtop = height - y
                uptrianglesmax = min(residualright, residualtop)
                faceups = faceups + uptrianglesmax
                downtrianglesmax = min(residualright,y)
                facedowns = facedowns + downtrianglesmax
        bases.append(base)
        heights.append(height)
        triangle_sums.append(faceups + facedowns)
        if (print_info):
            print("base=",base,"  height=",height)
            print("number of facing up triangles = ", faceups)
            print("number of facing down triangles = ", facedowns)
            print("Total Number of Triangles in this Trapezium =" , faceups + facedowns)
        
npbases = np.asarray(bases)
npheights =np.asarray(heights)

triangle_data_b_odd_lt_2h={
             'b':npbases,
             'h':npheights,
             'b^2':npbases**2,
             'b^3':npbases**3,
             'h^2':npheights**2,
             'h^3':npheights**3,
             'h^2*b': (npheights**2)*npbases,
             'b^2*h': (npbases**2)*npheights,
             'b*h':npbases*npheights,
             'Triangles':triangle_sums}


df = DataFrame(triangle_data_b_odd_lt_2h,columns=variables_list)

X = df[variables_list[:-1]]
Y = df[variables_list[-1]]


# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)


#Using the results from regr.intercept_ regr.coef_ to contruct a formula string
formula_string='Formula b_odd < 2h \nTriangle sum ='
if (abs(regr.intercept_)>10**-6):
    formula_string+=' {:.5f}'.format(regr.intercept_ )
    
for c, v in zip(regr.coef_, variables_list):
    if (abs(c)> 10**-6):
        formula_string+= ' +{:.4f}'.format(c) + v
        
print(formula_string+'\n')    

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Formula b_odd < 2h
# Triangle sum = -0.12500 +0.0833b +0.1667h +0.1250b^2 +-0.0833b^3 +-0.1667h^3 +0.5000b^2*h +0.5000b*h
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Triangles   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 7.795e+28
# Date:                Mon, 16 Nov 2020   Prob (F-statistic):               0.00
# Time:                        12:54:48   Log-Likelihood:                 2905.8
# No. Observations:                 128   AIC:                            -5792.
# Df Residuals:                     118   BIC:                            -5763.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1250   3.71e-11  -3.37e+09      0.000      -0.125      -0.125
# b              0.0833   1.29e-11   6.48e+09      0.000       0.083       0.083
# h              0.1667   1.76e-11   9.46e+09      0.000       0.167       0.167
# b^2            0.1250   1.32e-12   9.49e+10      0.000       0.125       0.125
# b^3           -0.0833   4.26e-14  -1.95e+12      0.000      -0.083      -0.083
# h^2         1.279e-13   2.56e-12      0.050      0.960   -4.95e-12    5.21e-12
# h^3           -0.1667   1.21e-13  -1.38e+12      0.000      -0.167      -0.167
# h^2*b        2.22e-14   2.17e-13      0.102      0.919   -4.08e-13    4.53e-13
# b^2*h          0.5000   1.54e-13   3.25e+12      0.000       0.500       0.500
# b*h            0.5000   3.27e-12   1.53e+11      0.000       0.500       0.500
# ==============================================================================
# Omnibus:                       26.031   Durbin-Watson:                   0.853
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.398
# Skew:                           1.231   Prob(JB):                     3.39e-08
# Kurtosis:                       3.620   Cond. No.                     3.27e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.27e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Case 3: base < 2*height, base = even integer

# %%
print_info = False
max_height = 25
max_base = 35
variables_list=['b','h','b^2','b^3','h^2','h^3','h^2*b','b^2*h','b*h','Triangles']


bases =[]
heights=[]
triangle_sums=[]

# Case that b < 2h, base = even
for height_count in range (1, max_height+1):
    height = height_count
    for base_count in range (height_count+1 , max_base+1):
        base = base_count
        if ( base > 2*height or (base%2)):
            continue
        faceups = 0
        facedowns = 0
        for y in range(0, height + 1):
            for x in range (0,base -y + 1):
                residualright = base -y - x
                residualtop = height - y
                uptrianglesmax = min(residualright, residualtop)
                faceups = faceups + uptrianglesmax
                downtrianglesmax = min(residualright,y)
                facedowns = facedowns + downtrianglesmax
        bases.append(base)
        heights.append(height)
        triangle_sums.append(faceups + facedowns)
        if (print_info):
            print("base=",base,"  height=",height)
            print("number of facing up triangles = ", faceups)
            print("number of facing down triangles = ", facedowns)
            print("Total Number of Triangles in this Trapezium =" , faceups + facedowns)
        
npbases = np.asarray(bases)
npheights =np.asarray(heights)

triangle_data_b_even_lt_2h={
             'b':npbases,
             'h':npheights,
             'b^2':npbases**2,
             'b^3':npbases**3,
             'h^2':npheights**2,
             'h^3':npheights**3,
             'h^2*b': (npheights**2)*npbases,
             'b^2*h': (npbases**2)*npheights,
             'b*h':npbases*npheights,
             'Triangles':triangle_sums}


df = DataFrame(triangle_data_b_even_lt_2h,columns=variables_list)

X = df[variables_list[:-1]]
Y = df[variables_list[-1]]


# with sklearn
regr = linear_model.LinearRegression()
regr.fit(X, Y)


#Using the results from regr.intercept_ regr.coef_ to contruct a formula string
formula_string='Formula b_even < 2h \nTriangle sum ='
if (abs(regr.intercept_)>10**-6):
    formula_string+=' {:.5f}'.format(regr.intercept_ )
    
for c, v in zip(regr.coef_, variables_list):
    if (abs(c)> 10**-6):
        formula_string+= ' +{:.4f}'.format(c) + v
        
print(formula_string+'\n')    

# with statsmodels
X = sm.add_constant(X) # adding a constant
 
model = sm.OLS(Y, X).fit()
predictions = model.predict(X) 
 
print_model = model.summary()
print(print_model)
# Out:
# Formula b_even < 2h
# Triangle sum = +0.0833b +0.1667h +0.1250b^2 +-0.0833b^3 +-0.1667h^3 +0.5000b^2*h +0.5000b*h
#
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              Triangles   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 1.966e+29
# Date:                Mon, 16 Nov 2020   Prob (F-statistic):               0.00
# Time:                        13:10:01   Log-Likelihood:                 3085.7
# No. Observations:                 133   AIC:                            -6151.
# Df Residuals:                     123   BIC:                            -6122.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       4.206e-12   1.85e-11      0.228      0.820   -3.23e-11    4.08e-11
# b              0.0833    7.1e-12   1.17e+10      0.000       0.083       0.083
# h              0.1667   8.99e-12   1.85e+10      0.000       0.167       0.167
# b^2            0.1250   7.61e-13   1.64e+11      0.000       0.125       0.125
# b^3           -0.0833    2.5e-14  -3.34e+12      0.000      -0.083      -0.083
# h^2         1.421e-13   1.33e-12      0.107      0.915   -2.49e-12    2.78e-12
# h^3           -0.1667   6.12e-14  -2.72e+12      0.000      -0.167      -0.167
# h^2*b       4.441e-15   1.15e-13      0.038      0.969   -2.24e-13    2.33e-13
# b^2*h          0.5000   8.63e-14   5.79e+12      0.000       0.500       0.500
# b*h            0.5000    1.8e-12   2.77e+11      0.000       0.500       0.500
# ==============================================================================
# Omnibus:                       15.540   Durbin-Watson:                   0.145
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               18.469
# Skew:                          -0.908   Prob(JB):                     9.76e-05
# Kurtosis:                       2.811   Cond. No.                     2.58e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Verifying the triangle sum formulae against bruteforce calculations

# %%
def trapezium_trianglesum_by_formula(b, h):
    case = 'none'
    #This calculates the number of triangles in the trapezium provided base >=2height
    faceups = h*(1 + h)*(2 + 3*b - 2*h)/6
    if ( b >= 2*h ):
        case = 'b >= 2h'
        facedowns = (b - h)*h*(1 + h)/2
    elif(b < 2*h):
        case = 'b < 2h'
        facedowns = (2*(b**2 - 1)*(2*b + 3) + 3*(1 + (-1)**b) - 8*(b - h - 1)*(b - h)*(b - h + 1))/48
    return (int(faceups),int(facedowns),int(faceups+facedowns), case)

# %%
def trapezium_trianglesum_bruteforce(base,height):    
    #Code for counting the triangles within a trapezium with a brute force algorithm 
    faceups = 0
    facedowns = 0
    for y in range(0, height + 1):
        for x in range (0,base -y + 1):
            residualright = base -y - x
            residualtop = height - y
            uptrianglesmax = min(residualright, residualtop)
            faceups = faceups + uptrianglesmax
            downtrianglesmax = min(residualright,y)
            facedowns = facedowns + downtrianglesmax
    return (faceups,facedowns,faceups+facedowns)

# %%
#Comparing the trapezium triangle sum calculated by formula to the brute force calculations
for base in range(1,20):
    for height in range(1,base):
        a = np.asarray(trapezium_trianglesum_bruteforce(base,height))
        b = np.asarray(trapezium_trianglesum_by_formula(base,height)[0:3])
        match = False
        if (np.linalg.norm(a-b) <1):
            match = True
        print("\nbase=",base, "height=",height,
              '\nBrute force sum [up, down, total] =',a,
              '\nFormula sum     [up, down, total] =',b,'   match=', match)
# Out:
# base= 2 height= 1
# Brute force sum [up, down, total] = [2 1 3]
# Formula sum     [up, down, total] = [2 1 3]    match= True
#
# base= 3 height= 1
# Brute force sum [up, down, total] = [3 2 5]
# Formula sum     [up, down, total] = [3 2 5]    match= True
#
# base= 3 height= 2
# Brute force sum [up, down, total] = [ 7  3 10]
# Formula sum     [up, down, total] = [ 7  3 10]    match= True
#
# base= 4 height= 1
# Brute force sum [up, down, total] = [4 3 7]
# Formula sum     [up, down, total] = [4 3 7]    match= True
#
# base= 4 height= 2
# Brute force sum [up, down, total] = [10  6 16]
# Formula sum     [up, down, total] = [10  6 16]    match= True
#
# base= 4 height= 3
# Brute force sum [up, down, total] = [16  7 23]
# Formula sum     [up, down, total] = [16  7 23]    match= True
#
# base= 5 height= 1
# Brute force sum [up, down, total] = [5 4 9]
# Formula sum     [up, down, total] = [5 4 9]    match= True
#
# base= 5 height= 2
# Brute force sum [up, down, total] = [13  9 22]
# Formula sum     [up, down, total] = [13  9 22]    match= True
#
# base= 5 height= 3
# Brute force sum [up, down, total] = [22 12 34]
# Formula sum     [up, down, total] = [22 12 34]    match= True
#
# base= 5 height= 4
# Brute force sum [up, down, total] = [30 13 43]
# Formula sum     [up, down, total] = [30 13 43]    match= True
#
# base= 6 height= 1
# Brute force sum [up, down, total] = [ 6  5 11]
# Formula sum     [up, down, total] = [ 6  5 11]    match= True
#
# base= 6 height= 2
# Brute force sum [up, down, total] = [16 12 28]
# Formula sum     [up, down, total] = [16 12 28]    match= True
#
# base= 6 height= 3
# Brute force sum [up, down, total] = [28 18 46]
# Formula sum     [up, down, total] = [28 18 46]    match= True
#
# base= 6 height= 4
# Brute force sum [up, down, total] = [40 21 61]
# Formula sum     [up, down, total] = [40 21 61]    match= True
#
# base= 6 height= 5
# Brute force sum [up, down, total] = [50 22 72]
# Formula sum     [up, down, total] = [50 22 72]    match= True
#
# base= 7 height= 1
# Brute force sum [up, down, total] = [ 7  6 13]
# Formula sum     [up, down, total] = [ 7  6 13]    match= True
#
# base= 7 height= 2
# Brute force sum [up, down, total] = [19 15 34]
# Formula sum     [up, down, total] = [19 15 34]    match= True
#
# base= 7 height= 3
# Brute force sum [up, down, total] = [34 24 58]
# Formula sum     [up, down, total] = [34 24 58]    match= True
#
# base= 7 height= 4
# Brute force sum [up, down, total] = [50 30 80]
# Formula sum     [up, down, total] = [50 30 80]    match= True
#
# base= 7 height= 5
# Brute force sum [up, down, total] = [65 33 98]
# Formula sum     [up, down, total] = [65 33 98]    match= True
#
# base= 7 height= 6
# Brute force sum [up, down, total] = [ 77  34 111]
# Formula sum     [up, down, total] = [ 77  34 111]    match= True
#
# base= 8 height= 1
# Brute force sum [up, down, total] = [ 8  7 15]
# Formula sum     [up, down, total] = [ 8  7 15]    match= True
#
# base= 8 height= 2
# Brute force sum [up, down, total] = [22 18 40]
# Formula sum     [up, down, total] = [22 18 40]    match= True
#
# base= 8 height= 3
# Brute force sum [up, down, total] = [40 30 70]
# Formula sum     [up, down, total] = [40 30 70]    match= True
#
# base= 8 height= 4
# Brute force sum [up, down, total] = [ 60  40 100]
# Formula sum     [up, down, total] = [ 60  40 100]    match= True
#
# base= 8 height= 5
# Brute force sum [up, down, total] = [ 80  46 126]
# Formula sum     [up, down, total] = [ 80  46 126]    match= True
#
# base= 8 height= 6
# Brute force sum [up, down, total] = [ 98  49 147]
# Formula sum     [up, down, total] = [ 98  49 147]    match= True
#
# base= 8 height= 7
# Brute force sum [up, down, total] = [112  50 162]
# Formula sum     [up, down, total] = [112  50 162]    match= True
#
# base= 9 height= 1
# Brute force sum [up, down, total] = [ 9  8 17]
# Formula sum     [up, down, total] = [ 9  8 17]    match= True
#
# base= 9 height= 2
# Brute force sum [up, down, total] = [25 21 46]
# Formula sum     [up, down, total] = [25 21 46]    match= True
#
# base= 9 height= 3
# Brute force sum [up, down, total] = [46 36 82]
# Formula sum     [up, down, total] = [46 36 82]    match= True
#
# base= 9 height= 4
# Brute force sum [up, down, total] = [ 70  50 120]
# Formula sum     [up, down, total] = [ 70  50 120]    match= True
#
# base= 9 height= 5
# Brute force sum [up, down, total] = [ 95  60 155]
# Formula sum     [up, down, total] = [ 95  60 155]    match= True
#
# base= 9 height= 6
# Brute force sum [up, down, total] = [119  66 185]
# Formula sum     [up, down, total] = [119  66 185]    match= True
#
# base= 9 height= 7
# Brute force sum [up, down, total] = [140  69 209]
# Formula sum     [up, down, total] = [140  69 209]    match= True
#
# base= 9 height= 8
# Brute force sum [up, down, total] = [156  70 226]
# Formula sum     [up, down, total] = [156  70 226]    match= True
#
# base= 10 height= 1
# Brute force sum [up, down, total] = [10  9 19]
# Formula sum     [up, down, total] = [10  9 19]    match= True
#
# base= 10 height= 2
# Brute force sum [up, down, total] = [28 24 52]
# Formula sum     [up, down, total] = [28 24 52]    match= True
#
# base= 10 height= 3
# Brute force sum [up, down, total] = [52 42 94]
# Formula sum     [up, down, total] = [52 42 94]    match= True
#
# base= 10 height= 4
# Brute force sum [up, down, total] = [ 80  60 140]
# Formula sum     [up, down, total] = [ 80  60 140]    match= True
#
# base= 10 height= 5
# Brute force sum [up, down, total] = [110  75 185]
# Formula sum     [up, down, total] = [110  75 185]    match= True
#
# base= 10 height= 6
# Brute force sum [up, down, total] = [140  85 225]
# Formula sum     [up, down, total] = [140  85 225]    match= True
#
# base= 10 height= 7
# Brute force sum [up, down, total] = [168  91 259]
# Formula sum     [up, down, total] = [168  91 259]    match= True
#
# base= 10 height= 8
# Brute force sum [up, down, total] = [192  94 286]
# Formula sum     [up, down, total] = [192  94 286]    match= True
#
# base= 10 height= 9
# Brute force sum [up, down, total] = [210  95 305]
# Formula sum     [up, down, total] = [210  95 305]    match= True
#
# base= 11 height= 1
# Brute force sum [up, down, total] = [11 10 21]
# Formula sum     [up, down, total] = [11 10 21]    match= True
#
# base= 11 height= 2
# Brute force sum [up, down, total] = [31 27 58]
# Formula sum     [up, down, total] = [31 27 58]    match= True
#
# base= 11 height= 3
# Brute force sum [up, down, total] = [ 58  48 106]
# Formula sum     [up, down, total] = [ 58  48 106]    match= True
#
# base= 11 height= 4
# Brute force sum [up, down, total] = [ 90  70 160]
# Formula sum     [up, down, total] = [ 90  70 160]    match= True
#
# base= 11 height= 5
# Brute force sum [up, down, total] = [125  90 215]
# Formula sum     [up, down, total] = [125  90 215]    match= True
#
# base= 11 height= 6
# Brute force sum [up, down, total] = [161 105 266]
# Formula sum     [up, down, total] = [161 105 266]    match= True
#
# base= 11 height= 7
# Brute force sum [up, down, total] = [196 115 311]
# Formula sum     [up, down, total] = [196 115 311]    match= True
#
# base= 11 height= 8
# Brute force sum [up, down, total] = [228 121 349]
# Formula sum     [up, down, total] = [228 121 349]    match= True
#
# base= 11 height= 9
# Brute force sum [up, down, total] = [255 124 379]
# Formula sum     [up, down, total] = [255 124 379]    match= True
#
# base= 11 height= 10
# Brute force sum [up, down, total] = [275 125 400]
# Formula sum     [up, down, total] = [275 125 400]    match= True
#
# base= 12 height= 1
# Brute force sum [up, down, total] = [12 11 23]
# Formula sum     [up, down, total] = [12 11 23]    match= True
#
# base= 12 height= 2
# Brute force sum [up, down, total] = [34 30 64]
# Formula sum     [up, down, total] = [34 30 64]    match= True
#
# base= 12 height= 3
# Brute force sum [up, down, total] = [ 64  54 118]
# Formula sum     [up, down, total] = [ 64  54 118]    match= True
#
# base= 12 height= 4
# Brute force sum [up, down, total] = [100  80 180]
# Formula sum     [up, down, total] = [100  80 180]    match= True
#
# base= 12 height= 5
# Brute force sum [up, down, total] = [140 105 245]
# Formula sum     [up, down, total] = [140 105 245]    match= True
#
# base= 12 height= 6
# Brute force sum [up, down, total] = [182 126 308]
# Formula sum     [up, down, total] = [182 126 308]    match= True
#
# base= 12 height= 7
# Brute force sum [up, down, total] = [224 141 365]
# Formula sum     [up, down, total] = [224 141 365]    match= True
#
# base= 12 height= 8
# Brute force sum [up, down, total] = [264 151 415]
# Formula sum     [up, down, total] = [264 151 415]    match= True
#
# base= 12 height= 9
# Brute force sum [up, down, total] = [300 157 457]
# Formula sum     [up, down, total] = [300 157 457]    match= True
#
# base= 12 height= 10
# Brute force sum [up, down, total] = [330 160 490]
# Formula sum     [up, down, total] = [330 160 490]    match= True
#
# base= 12 height= 11
# Brute force sum [up, down, total] = [352 161 513]
# Formula sum     [up, down, total] = [352 161 513]    match= True
#
# base= 13 height= 1
# Brute force sum [up, down, total] = [13 12 25]
# Formula sum     [up, down, total] = [13 12 25]    match= True
#
# base= 13 height= 2
# Brute force sum [up, down, total] = [37 33 70]
# Formula sum     [up, down, total] = [37 33 70]    match= True
#
# base= 13 height= 3
# Brute force sum [up, down, total] = [ 70  60 130]
# Formula sum     [up, down, total] = [ 70  60 130]    match= True
#
# base= 13 height= 4
# Brute force sum [up, down, total] = [110  90 200]
# Formula sum     [up, down, total] = [110  90 200]    match= True
#
# base= 13 height= 5
# Brute force sum [up, down, total] = [155 120 275]
# Formula sum     [up, down, total] = [155 120 275]    match= True
#
# base= 13 height= 6
# Brute force sum [up, down, total] = [203 147 350]
# Formula sum     [up, down, total] = [203 147 350]    match= True
#
# base= 13 height= 7
# Brute force sum [up, down, total] = [252 168 420]
# Formula sum     [up, down, total] = [252 168 420]    match= True
#
# base= 13 height= 8
# Brute force sum [up, down, total] = [300 183 483]
# Formula sum     [up, down, total] = [300 183 483]    match= True
#
# base= 13 height= 9
# Brute force sum [up, down, total] = [345 193 538]
# Formula sum     [up, down, total] = [345 193 538]    match= True
#
# base= 13 height= 10
# Brute force sum [up, down, total] = [385 199 584]
# Formula sum     [up, down, total] = [385 199 584]    match= True
#
# base= 13 height= 11
# Brute force sum [up, down, total] = [418 202 620]
# Formula sum     [up, down, total] = [418 202 620]    match= True
#
# base= 13 height= 12
# Brute force sum [up, down, total] = [442 203 645]
# Formula sum     [up, down, total] = [442 203 645]    match= True
#
# base= 14 height= 1
# Brute force sum [up, down, total] = [14 13 27]
# Formula sum     [up, down, total] = [14 13 27]    match= True
#
# base= 14 height= 2
# Brute force sum [up, down, total] = [40 36 76]
# Formula sum     [up, down, total] = [40 36 76]    match= True
#
# base= 14 height= 3
# Brute force sum [up, down, total] = [ 76  66 142]
# Formula sum     [up, down, total] = [ 76  66 142]    match= True
#
# base= 14 height= 4
# Brute force sum [up, down, total] = [120 100 220]
# Formula sum     [up, down, total] = [120 100 220]    match= True
#
# base= 14 height= 5
# Brute force sum [up, down, total] = [170 135 305]
# Formula sum     [up, down, total] = [170 135 305]    match= True
#
# base= 14 height= 6
# Brute force sum [up, down, total] = [224 168 392]
# Formula sum     [up, down, total] = [224 168 392]    match= True
#
# base= 14 height= 7
# Brute force sum [up, down, total] = [280 196 476]
# Formula sum     [up, down, total] = [280 196 476]    match= True
#
# base= 14 height= 8
# Brute force sum [up, down, total] = [336 217 553]
# Formula sum     [up, down, total] = [336 217 553]    match= True
#
# base= 14 height= 9
# Brute force sum [up, down, total] = [390 232 622]
# Formula sum     [up, down, total] = [390 232 622]    match= True
#
# base= 14 height= 10
# Brute force sum [up, down, total] = [440 242 682]
# Formula sum     [up, down, total] = [440 242 682]    match= True
#
# base= 14 height= 11
# Brute force sum [up, down, total] = [484 248 732]
# Formula sum     [up, down, total] = [484 248 732]    match= True
#
# base= 14 height= 12
# Brute force sum [up, down, total] = [520 251 771]
# Formula sum     [up, down, total] = [520 251 771]    match= True
#
# base= 14 height= 13
# Brute force sum [up, down, total] = [546 252 798]
# Formula sum     [up, down, total] = [546 252 798]    match= True
#
# base= 15 height= 1
# Brute force sum [up, down, total] = [15 14 29]
# Formula sum     [up, down, total] = [15 14 29]    match= True
#
# base= 15 height= 2
# Brute force sum [up, down, total] = [43 39 82]
# Formula sum     [up, down, total] = [43 39 82]    match= True
#
# base= 15 height= 3
# Brute force sum [up, down, total] = [ 82  72 154]
# Formula sum     [up, down, total] = [ 82  72 154]    match= True
#
# base= 15 height= 4
# Brute force sum [up, down, total] = [130 110 240]
# Formula sum     [up, down, total] = [130 110 240]    match= True
#
# base= 15 height= 5
# Brute force sum [up, down, total] = [185 150 335]
# Formula sum     [up, down, total] = [185 150 335]    match= True
#
# base= 15 height= 6
# Brute force sum [up, down, total] = [245 189 434]
# Formula sum     [up, down, total] = [245 189 434]    match= True
#
# base= 15 height= 7
# Brute force sum [up, down, total] = [308 224 532]
# Formula sum     [up, down, total] = [308 224 532]    match= True
#
# base= 15 height= 8
# Brute force sum [up, down, total] = [372 252 624]
# Formula sum     [up, down, total] = [372 252 624]    match= True
#
# base= 15 height= 9
# Brute force sum [up, down, total] = [435 273 708]
# Formula sum     [up, down, total] = [435 273 708]    match= True
#
# base= 15 height= 10
# Brute force sum [up, down, total] = [495 288 783]
# Formula sum     [up, down, total] = [495 288 783]    match= True
#
# base= 15 height= 11
# Brute force sum [up, down, total] = [550 298 848]
# Formula sum     [up, down, total] = [550 298 848]    match= True
#
# base= 15 height= 12
# Brute force sum [up, down, total] = [598 304 902]
# Formula sum     [up, down, total] = [598 304 902]    match= True
#
# base= 15 height= 13
# Brute force sum [up, down, total] = [637 307 944]
# Formula sum     [up, down, total] = [637 307 944]    match= True
#
# base= 15 height= 14
# Brute force sum [up, down, total] = [665 308 973]
# Formula sum     [up, down, total] = [665 308 973]    match= True
#
# base= 16 height= 1
# Brute force sum [up, down, total] = [16 15 31]
# Formula sum     [up, down, total] = [16 15 31]    match= True
#
# base= 16 height= 2
# Brute force sum [up, down, total] = [46 42 88]
# Formula sum     [up, down, total] = [46 42 88]    match= True
#
# base= 16 height= 3
# Brute force sum [up, down, total] = [ 88  78 166]
# Formula sum     [up, down, total] = [ 88  78 166]    match= True
#
# base= 16 height= 4
# Brute force sum [up, down, total] = [140 120 260]
# Formula sum     [up, down, total] = [140 120 260]    match= True
#
# base= 16 height= 5
# Brute force sum [up, down, total] = [200 165 365]
# Formula sum     [up, down, total] = [200 165 365]    match= True
#
# base= 16 height= 6
# Brute force sum [up, down, total] = [266 210 476]
# Formula sum     [up, down, total] = [266 210 476]    match= True
#
# base= 16 height= 7
# Brute force sum [up, down, total] = [336 252 588]
# Formula sum     [up, down, total] = [336 252 588]    match= True
#
# base= 16 height= 8
# Brute force sum [up, down, total] = [408 288 696]
# Formula sum     [up, down, total] = [408 288 696]    match= True
#
# base= 16 height= 9
# Brute force sum [up, down, total] = [480 316 796]
# Formula sum     [up, down, total] = [480 316 796]    match= True
#
# base= 16 height= 10
# Brute force sum [up, down, total] = [550 337 887]
# Formula sum     [up, down, total] = [550 337 887]    match= True
#
# base= 16 height= 11
# Brute force sum [up, down, total] = [616 352 968]
# Formula sum     [up, down, total] = [616 352 968]    match= True
#
# base= 16 height= 12
# Brute force sum [up, down, total] = [ 676  362 1038]
# Formula sum     [up, down, total] = [ 676  362 1038]    match= True
#
# base= 16 height= 13
# Brute force sum [up, down, total] = [ 728  368 1096]
# Formula sum     [up, down, total] = [ 728  368 1096]    match= True
#
# base= 16 height= 14
# Brute force sum [up, down, total] = [ 770  371 1141]
# Formula sum     [up, down, total] = [ 770  371 1141]    match= True
#
# base= 16 height= 15
# Brute force sum [up, down, total] = [ 800  372 1172]
# Formula sum     [up, down, total] = [ 800  372 1172]    match= True
#
# base= 17 height= 1
# Brute force sum [up, down, total] = [17 16 33]
# Formula sum     [up, down, total] = [17 16 33]    match= True
#
# base= 17 height= 2
# Brute force sum [up, down, total] = [49 45 94]
# Formula sum     [up, down, total] = [49 45 94]    match= True
#
# base= 17 height= 3
# Brute force sum [up, down, total] = [ 94  84 178]
# Formula sum     [up, down, total] = [ 94  84 178]    match= True
#
# base= 17 height= 4
# Brute force sum [up, down, total] = [150 130 280]
# Formula sum     [up, down, total] = [150 130 280]    match= True
#
# base= 17 height= 5
# Brute force sum [up, down, total] = [215 180 395]
# Formula sum     [up, down, total] = [215 180 395]    match= True
#
# base= 17 height= 6
# Brute force sum [up, down, total] = [287 231 518]
# Formula sum     [up, down, total] = [287 231 518]    match= True
#
# base= 17 height= 7
# Brute force sum [up, down, total] = [364 280 644]
# Formula sum     [up, down, total] = [364 280 644]    match= True
#
# base= 17 height= 8
# Brute force sum [up, down, total] = [444 324 768]
# Formula sum     [up, down, total] = [444 324 768]    match= True
#
# base= 17 height= 9
# Brute force sum [up, down, total] = [525 360 885]
# Formula sum     [up, down, total] = [525 360 885]    match= True
#
# base= 17 height= 10
# Brute force sum [up, down, total] = [605 388 993]
# Formula sum     [up, down, total] = [605 388 993]    match= True
#
# base= 17 height= 11
# Brute force sum [up, down, total] = [ 682  409 1091]
# Formula sum     [up, down, total] = [ 682  409 1091]    match= True
#
# base= 17 height= 12
# Brute force sum [up, down, total] = [ 754  424 1178]
# Formula sum     [up, down, total] = [ 754  424 1178]    match= True
#
# base= 17 height= 13
# Brute force sum [up, down, total] = [ 819  434 1253]
# Formula sum     [up, down, total] = [ 819  434 1253]    match= True
#
# base= 17 height= 14
# Brute force sum [up, down, total] = [ 875  440 1315]
# Formula sum     [up, down, total] = [ 875  440 1315]    match= True
#
# base= 17 height= 15
# Brute force sum [up, down, total] = [ 920  443 1363]
# Formula sum     [up, down, total] = [ 920  443 1363]    match= True
#
# base= 17 height= 16
# Brute force sum [up, down, total] = [ 952  444 1396]
# Formula sum     [up, down, total] = [ 952  444 1396]    match= True
#
# base= 18 height= 1
# Brute force sum [up, down, total] = [18 17 35]
# Formula sum     [up, down, total] = [18 17 35]    match= True
#
# base= 18 height= 2
# Brute force sum [up, down, total] = [ 52  48 100]
# Formula sum     [up, down, total] = [ 52  48 100]    match= True
#
# base= 18 height= 3
# Brute force sum [up, down, total] = [100  90 190]
# Formula sum     [up, down, total] = [100  90 190]    match= True
#
# base= 18 height= 4
# Brute force sum [up, down, total] = [160 140 300]
# Formula sum     [up, down, total] = [160 140 300]    match= True
#
# base= 18 height= 5
# Brute force sum [up, down, total] = [230 195 425]
# Formula sum     [up, down, total] = [230 195 425]    match= True
#
# base= 18 height= 6
# Brute force sum [up, down, total] = [308 252 560]
# Formula sum     [up, down, total] = [308 252 560]    match= True
#
# base= 18 height= 7
# Brute force sum [up, down, total] = [392 308 700]
# Formula sum     [up, down, total] = [392 308 700]    match= True
#
# base= 18 height= 8
# Brute force sum [up, down, total] = [480 360 840]
# Formula sum     [up, down, total] = [480 360 840]    match= True
#
# base= 18 height= 9
# Brute force sum [up, down, total] = [570 405 975]
# Formula sum     [up, down, total] = [570 405 975]    match= True
#
# base= 18 height= 10
# Brute force sum [up, down, total] = [ 660  441 1101]
# Formula sum     [up, down, total] = [ 660  441 1101]    match= True
#
# base= 18 height= 11
# Brute force sum [up, down, total] = [ 748  469 1217]
# Formula sum     [up, down, total] = [ 748  469 1217]    match= True
#
# base= 18 height= 12
# Brute force sum [up, down, total] = [ 832  490 1322]
# Formula sum     [up, down, total] = [ 832  490 1322]    match= True
#
# base= 18 height= 13
# Brute force sum [up, down, total] = [ 910  505 1415]
# Formula sum     [up, down, total] = [ 910  505 1415]    match= True
#
# base= 18 height= 14
# Brute force sum [up, down, total] = [ 980  515 1495]
# Formula sum     [up, down, total] = [ 980  515 1495]    match= True
#
# base= 18 height= 15
# Brute force sum [up, down, total] = [1040  521 1561]
# Formula sum     [up, down, total] = [1040  521 1561]    match= True
#
# base= 18 height= 16
# Brute force sum [up, down, total] = [1088  524 1612]
# Formula sum     [up, down, total] = [1088  524 1612]    match= True
#
# base= 18 height= 17
# Brute force sum [up, down, total] = [1122  525 1647]
# Formula sum     [up, down, total] = [1122  525 1647]    match= True
#
# base= 19 height= 1
# Brute force sum [up, down, total] = [19 18 37]
# Formula sum     [up, down, total] = [19 18 37]    match= True
#
# base= 19 height= 2
# Brute force sum [up, down, total] = [ 55  51 106]
# Formula sum     [up, down, total] = [ 55  51 106]    match= True
#
# base= 19 height= 3
# Brute force sum [up, down, total] = [106  96 202]
# Formula sum     [up, down, total] = [106  96 202]    match= True
#
# base= 19 height= 4
# Brute force sum [up, down, total] = [170 150 320]
# Formula sum     [up, down, total] = [170 150 320]    match= True
#
# base= 19 height= 5
# Brute force sum [up, down, total] = [245 210 455]
# Formula sum     [up, down, total] = [245 210 455]    match= True
#
# base= 19 height= 6
# Brute force sum [up, down, total] = [329 273 602]
# Formula sum     [up, down, total] = [329 273 602]    match= True
#
# base= 19 height= 7
# Brute force sum [up, down, total] = [420 336 756]
# Formula sum     [up, down, total] = [420 336 756]    match= True
#
# base= 19 height= 8
# Brute force sum [up, down, total] = [516 396 912]
# Formula sum     [up, down, total] = [516 396 912]    match= True
#
# base= 19 height= 9
# Brute force sum [up, down, total] = [ 615  450 1065]
# Formula sum     [up, down, total] = [ 615  450 1065]    match= True
#
# base= 19 height= 10
# Brute force sum [up, down, total] = [ 715  495 1210]
# Formula sum     [up, down, total] = [ 715  495 1210]    match= True
#
# base= 19 height= 11
# Brute force sum [up, down, total] = [ 814  531 1345]
# Formula sum     [up, down, total] = [ 814  531 1345]    match= True
#
# base= 19 height= 12
# Brute force sum [up, down, total] = [ 910  559 1469]
# Formula sum     [up, down, total] = [ 910  559 1469]    match= True
#
# base= 19 height= 13
# Brute force sum [up, down, total] = [1001  580 1581]
# Formula sum     [up, down, total] = [1001  580 1581]    match= True
#
# base= 19 height= 14
# Brute force sum [up, down, total] = [1085  595 1680]
# Formula sum     [up, down, total] = [1085  595 1680]    match= True
#
# base= 19 height= 15
# Brute force sum [up, down, total] = [1160  605 1765]
# Formula sum     [up, down, total] = [1160  605 1765]    match= True
#
# base= 19 height= 16
# Brute force sum [up, down, total] = [1224  611 1835]
# Formula sum     [up, down, total] = [1224  611 1835]    match= True
#
# base= 19 height= 17
# Brute force sum [up, down, total] = [1275  614 1889]
# Formula sum     [up, down, total] = [1275  614 1889]    match= True
#
# base= 19 height= 18
# Brute force sum [up, down, total] = [1311  615 1926]
# Formula sum     [up, down, total] = [1311  615 1926]    match= True

# %% [markdown]
# ## Code snippets for investigating the triangle sum patterns
# The first code block tabulates the base height and triangle sums in a table format.
# The second code block prints out the changes (delta sum) in the triangle sum for each base and height combination.

# %%
print(tabulate(df[['b','h','Triangles']], headers='keys', tablefmt='psql'))
# Out:
# +-----+-----+-----+-------------+
# |     |   b |   h |   Triangles |
# |-----+-----+-----+-------------|
# |   0 |   2 |   1 |           3 |
# |   1 |   4 |   2 |          16 |
# |   2 |   4 |   3 |          23 |
# |   3 |   6 |   3 |          46 |
# |   4 |   6 |   4 |          61 |
# |   5 |   8 |   4 |         100 |
# |   6 |   6 |   5 |          72 |
# |   7 |   8 |   5 |         126 |
# |   8 |  10 |   5 |         185 |
# |   9 |   8 |   6 |         147 |
# |  10 |  10 |   6 |         225 |
# |  11 |  12 |   6 |         308 |
# |  12 |   8 |   7 |         162 |
# |  13 |  10 |   7 |         259 |
# |  14 |  12 |   7 |         365 |
# |  15 |  14 |   7 |         476 |
# |  16 |  10 |   8 |         286 |
# |  17 |  12 |   8 |         415 |
# |  18 |  14 |   8 |         553 |
# |  19 |  16 |   8 |         696 |
# |  20 |  10 |   9 |         305 |
# |  21 |  12 |   9 |         457 |
# |  22 |  14 |   9 |         622 |
# |  23 |  16 |   9 |         796 |
# |  24 |  18 |   9 |         975 |
# |  25 |  12 |  10 |         490 |
# |  26 |  14 |  10 |         682 |
# |  27 |  16 |  10 |         887 |
# |  28 |  18 |  10 |        1101 |
# |  29 |  20 |  10 |        1320 |
# |  30 |  12 |  11 |         513 |
# |  31 |  14 |  11 |         732 |
# |  32 |  16 |  11 |         968 |
# |  33 |  18 |  11 |        1217 |
# |  34 |  20 |  11 |        1475 |
# |  35 |  22 |  11 |        1738 |
# |  36 |  14 |  12 |         771 |
# |  37 |  16 |  12 |        1038 |
# |  38 |  18 |  12 |        1322 |
# |  39 |  20 |  12 |        1619 |
# |  40 |  22 |  12 |        1925 |
# |  41 |  24 |  12 |        2236 |
# |  42 |  14 |  13 |         798 |
# |  43 |  16 |  13 |        1096 |
# |  44 |  18 |  13 |        1415 |
# |  45 |  20 |  13 |        1751 |
# |  46 |  22 |  13 |        2100 |
# |  47 |  24 |  13 |        2458 |
# |  48 |  26 |  13 |        2821 |
# |  49 |  16 |  14 |        1141 |
# |  50 |  18 |  14 |        1495 |
# |  51 |  20 |  14 |        1870 |
# |  52 |  22 |  14 |        2262 |
# |  53 |  24 |  14 |        2667 |
# |  54 |  26 |  14 |        3081 |
# |  55 |  28 |  14 |        3500 |
# |  56 |  16 |  15 |        1172 |
# |  57 |  18 |  15 |        1561 |
# |  58 |  20 |  15 |        1975 |
# |  59 |  22 |  15 |        2410 |
# |  60 |  24 |  15 |        2862 |
# |  61 |  26 |  15 |        3327 |
# |  62 |  28 |  15 |        3801 |
# |  63 |  30 |  15 |        4280 |
# |  64 |  18 |  16 |        1612 |
# |  65 |  20 |  16 |        2065 |
# |  66 |  22 |  16 |        2543 |
# |  67 |  24 |  16 |        3042 |
# |  68 |  26 |  16 |        3558 |
# |  69 |  28 |  16 |        4087 |
# |  70 |  30 |  16 |        4625 |
# |  71 |  32 |  16 |        5168 |
# |  72 |  18 |  17 |        1647 |
# |  73 |  20 |  17 |        2139 |
# |  74 |  22 |  17 |        2660 |
# |  75 |  24 |  17 |        3206 |
# |  76 |  26 |  17 |        3773 |
# |  77 |  28 |  17 |        4357 |
# |  78 |  30 |  17 |        4954 |
# |  79 |  32 |  17 |        5560 |
# |  80 |  34 |  17 |        6171 |
# |  81 |  20 |  18 |        2196 |
# |  82 |  22 |  18 |        2760 |
# |  83 |  24 |  18 |        3353 |
# |  84 |  26 |  18 |        3971 |
# |  85 |  28 |  18 |        4610 |
# |  86 |  30 |  18 |        5266 |
# |  87 |  32 |  18 |        5935 |
# |  88 |  34 |  18 |        6613 |
# |  89 |  20 |  19 |        2235 |
# |  90 |  22 |  19 |        2842 |
# |  91 |  24 |  19 |        3482 |
# |  92 |  26 |  19 |        4151 |
# |  93 |  28 |  19 |        4845 |
# |  94 |  30 |  19 |        5560 |
# |  95 |  32 |  19 |        6292 |
# |  96 |  34 |  19 |        7037 |
# |  97 |  22 |  20 |        2905 |
# |  98 |  24 |  20 |        3592 |
# |  99 |  26 |  20 |        4312 |
# | 100 |  28 |  20 |        5061 |
# | 101 |  30 |  20 |        5835 |
# | 102 |  32 |  20 |        6630 |
# | 103 |  34 |  20 |        7442 |
# | 104 |  22 |  21 |        2948 |
# | 105 |  24 |  21 |        3682 |
# | 106 |  26 |  21 |        4453 |
# | 107 |  28 |  21 |        5257 |
# | 108 |  30 |  21 |        6090 |
# | 109 |  32 |  21 |        6948 |
# | 110 |  34 |  21 |        7827 |
# | 111 |  24 |  22 |        3751 |
# | 112 |  26 |  22 |        4573 |
# | 113 |  28 |  22 |        5432 |
# | 114 |  30 |  22 |        6324 |
# | 115 |  32 |  22 |        7245 |
# | 116 |  34 |  22 |        8191 |
# | 117 |  24 |  23 |        3798 |
# | 118 |  26 |  23 |        4671 |
# | 119 |  28 |  23 |        5585 |
# | 120 |  30 |  23 |        6536 |
# | 121 |  32 |  23 |        7520 |
# | 122 |  34 |  23 |        8533 |
# | 123 |  26 |  24 |        4746 |
# | 124 |  28 |  24 |        5715 |
# | 125 |  30 |  24 |        6725 |
# | 126 |  32 |  24 |        7772 |
# | 127 |  34 |  24 |        8852 |
# | 128 |  26 |  25 |        4797 |
# | 129 |  28 |  25 |        5821 |
# | 130 |  30 |  25 |        6890 |
# | 131 |  32 |  25 |        8000 |
# | 132 |  34 |  25 |        9147 |
# +-----+-----+-----+-------------+

# %%
for counter,value in enumerate(npbases):
    if( value%10 == 0):
         print('\nBase','\t','Heigh','\t','Trian','\t', 'Delta Sum','\n')
    if( counter + 1 < len(npbases)):
        diff = max(triangle_sums[counter+1]-triangle_sums[counter],0)
    else:
        diff = 0
    print(value,'\t',npheights[counter],'\t',triangle_sums[counter],'\t',diff)
# Out:
# 2 	 1 	 3 	 13
# 4 	 2 	 16 	 7
# 4 	 3 	 23 	 23
# 6 	 3 	 46 	 15
# 6 	 4 	 61 	 39
# 8 	 4 	 100 	 0
# 6 	 5 	 72 	 54
# 8 	 5 	 126 	 59
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 10 	 5 	 185 	 0
# 8 	 6 	 147 	 78
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 10 	 6 	 225 	 83
# 12 	 6 	 308 	 0
# 8 	 7 	 162 	 97
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 10 	 7 	 259 	 106
# 12 	 7 	 365 	 111
# 14 	 7 	 476 	 0
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 10 	 8 	 286 	 129
# 12 	 8 	 415 	 138
# 14 	 8 	 553 	 143
# 16 	 8 	 696 	 0
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 10 	 9 	 305 	 152
# 12 	 9 	 457 	 165
# 14 	 9 	 622 	 174
# 16 	 9 	 796 	 179
# 18 	 9 	 975 	 0
# 12 	 10 	 490 	 192
# 14 	 10 	 682 	 205
# 16 	 10 	 887 	 214
# 18 	 10 	 1101 	 219
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 10 	 1320 	 0
# 12 	 11 	 513 	 219
# 14 	 11 	 732 	 236
# 16 	 11 	 968 	 249
# 18 	 11 	 1217 	 258
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 11 	 1475 	 263
# 22 	 11 	 1738 	 0
# 14 	 12 	 771 	 267
# 16 	 12 	 1038 	 284
# 18 	 12 	 1322 	 297
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 12 	 1619 	 306
# 22 	 12 	 1925 	 311
# 24 	 12 	 2236 	 0
# 14 	 13 	 798 	 298
# 16 	 13 	 1096 	 319
# 18 	 13 	 1415 	 336
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 13 	 1751 	 349
# 22 	 13 	 2100 	 358
# 24 	 13 	 2458 	 363
# 26 	 13 	 2821 	 0
# 16 	 14 	 1141 	 354
# 18 	 14 	 1495 	 375
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 14 	 1870 	 392
# 22 	 14 	 2262 	 405
# 24 	 14 	 2667 	 414
# 26 	 14 	 3081 	 419
# 28 	 14 	 3500 	 0
# 16 	 15 	 1172 	 389
# 18 	 15 	 1561 	 414
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 15 	 1975 	 435
# 22 	 15 	 2410 	 452
# 24 	 15 	 2862 	 465
# 26 	 15 	 3327 	 474
# 28 	 15 	 3801 	 479
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 15 	 4280 	 0
# 18 	 16 	 1612 	 453
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 16 	 2065 	 478
# 22 	 16 	 2543 	 499
# 24 	 16 	 3042 	 516
# 26 	 16 	 3558 	 529
# 28 	 16 	 4087 	 538
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 16 	 4625 	 543
# 32 	 16 	 5168 	 0
# 18 	 17 	 1647 	 492
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 17 	 2139 	 521
# 22 	 17 	 2660 	 546
# 24 	 17 	 3206 	 567
# 26 	 17 	 3773 	 584
# 28 	 17 	 4357 	 597
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 17 	 4954 	 606
# 32 	 17 	 5560 	 611
# 34 	 17 	 6171 	 0
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 18 	 2196 	 564
# 22 	 18 	 2760 	 593
# 24 	 18 	 3353 	 618
# 26 	 18 	 3971 	 639
# 28 	 18 	 4610 	 656
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 18 	 5266 	 669
# 32 	 18 	 5935 	 678
# 34 	 18 	 6613 	 0
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 20 	 19 	 2235 	 607
# 22 	 19 	 2842 	 640
# 24 	 19 	 3482 	 669
# 26 	 19 	 4151 	 694
# 28 	 19 	 4845 	 715
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 19 	 5560 	 732
# 32 	 19 	 6292 	 745
# 34 	 19 	 7037 	 0
# 22 	 20 	 2905 	 687
# 24 	 20 	 3592 	 720
# 26 	 20 	 4312 	 749
# 28 	 20 	 5061 	 774
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 20 	 5835 	 795
# 32 	 20 	 6630 	 812
# 34 	 20 	 7442 	 0
# 22 	 21 	 2948 	 734
# 24 	 21 	 3682 	 771
# 26 	 21 	 4453 	 804
# 28 	 21 	 5257 	 833
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 21 	 6090 	 858
# 32 	 21 	 6948 	 879
# 34 	 21 	 7827 	 0
# 24 	 22 	 3751 	 822
# 26 	 22 	 4573 	 859
# 28 	 22 	 5432 	 892
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 22 	 6324 	 921
# 32 	 22 	 7245 	 946
# 34 	 22 	 8191 	 0
# 24 	 23 	 3798 	 873
# 26 	 23 	 4671 	 914
# 28 	 23 	 5585 	 951
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 23 	 6536 	 984
# 32 	 23 	 7520 	 1013
# 34 	 23 	 8533 	 0
# 26 	 24 	 4746 	 969
# 28 	 24 	 5715 	 1010
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 24 	 6725 	 1047
# 32 	 24 	 7772 	 1080
# 34 	 24 	 8852 	 0
# 26 	 25 	 4797 	 1024
# 28 	 25 	 5821 	 1069
#
# Base 	 Heigh 	 Trian 	 Delta Sum
#
# 30 	 25 	 6890 	 1110
# 32 	 25 	 8000 	 1147
# 34 	 25 	 9147 	 0
